# %% [markdown]
# # collab ile ilk çalışma
# merhaba ilk calısmama hosgeldim

# %%
print("merhaba, anlaşılır ekonomi ile veri eğitimi")
# Out:
# merhaba, anlaşılır ekonomi ile veri eğitimi

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 125806114681579526
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14619377664
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8458988153267741990
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]
