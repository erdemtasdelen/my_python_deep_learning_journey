# %%
import numpy as np
import matplotlib.pyplot as plt

R=np.array([[0,255,0], [255,0,255], [0,255,0]])
G=np.array([[0,0,255], [255,0,255], [255,255,0]])
B=np.array([[0,0,0], [255,255,0], [0,255,255]])

tensor=np.stack([R,G,B], axis=2)
print(tensor)
# Out:
# [[[  0   0   0]
#   [255   0   0]
#   [  0 255   0]]
#
#  [[255 255 255]
#   [  0   0 255]
#   [255 255   0]]
#
#  [[  0 255   0]
#   [255 255 255]
#   [  0   0 255]]]

# %%
plt.imshow(tensor)
plt.show()
#görsel şov
